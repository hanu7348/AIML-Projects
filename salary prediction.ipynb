# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt

# %%
salary = pd.read_csv('Salary Data.csv')
salary
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
salary.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
salary.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
# Prepare the data
X = salary[['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience']]
y = salary['Salary']

# %%
salary.dropna(inplace=True)
salary
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
print(X,y)
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience
# 0                    5.0
# 1                    3.0
# 2                   15.0
# 3                    7.0
# 4                   20.0
# ..                   ...
# ...

# %%
salary.fillna(0)
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
salary.fillna(0)
# Out:
#       Age  Gender Education Level                      Job Title  \
# 0    32.0    Male      Bachelor's              Software Engineer
# 1    28.0  Female        Master's                   Data Analyst
# 2    45.0    Male             PhD                 Senior Manager
# 3    36.0  Female      Bachelor's                Sales Associate
# 4    52.0    Male        Master's                       Director
# ..    ...     ...             ...                            ...
# 370  35.0  Female      Bachelor's       Senior Marketing Analyst
# 371  43.0    Male        Master's         Director of Operations
# 372  29.0  Female      Bachelor's         Junior Project Manager
# 373  34.0    Male      Bachelor's  Senior Operations Coordinator
# 374  44.0  Female             PhD        Senior Business Analyst
#
#      Years of Experience    Salary
# 0                    5.0   90000.0
# 1                    3.0   65000.0
# 2                   15.0  150000.0
# 3                    7.0   60000.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder instance for each categorical variable
le = LabelEncoder()


# Apply the same encoding to both datasets
salary['Education Level'] = le.fit_transform(salary['Education Level'])
salary['Gender'] = le.fit_transform(salary['Gender'])

# %%
salary.head()
# Out:
#     Age  Gender  Education Level          Job Title  Years of Experience  \
# 0  32.0       1                0  Software Engineer                  5.0
# 1  28.0       0                1       Data Analyst                  3.0
# 2  45.0       1                2     Senior Manager                 15.0
# 3  36.0       0                0    Sales Associate                  7.0
# 4  52.0       1                1           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
#create an empty model

# %%
from sklearn.preprocessing import LabelEncoder

# Create a LabelEncoder instance for each categorical variable
le = LabelEncoder()

# Apply the encoding and reassign to the DataFrame
salary['Education Level'] = le.fit_transform(salary['Education Level'])
salary['Gender'] = le.fit_transform(salary['Gender']) 
salary['Job Title'] = le.fit_transform(salary['Job Title']) 

# Prepare the data (after encoding)
X = salary[['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience']] 
y = salary['Salary']

#create an empty model
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
#user input
age=float(input("Enter age: "))
gen=int(input("Enter0 for male 1 for female: "))
el=int(input("Enter education level 0-Bachelors,1-Master,2-PhD: "))
exp=float(input("Enter years of experience: "))
out=model.predict([[age,gen,el,exp]])
print("Your Predicted salary is:",out[0])
# Out:
# Enter age:  45
# Enter0 for male 1 for female:  33
# Enter education level 0-Bachelors,1-Master,2-PhD:  4
# Enter years of experience:  3
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 el=int(input("Enter education level 0-Bachelors,1-Master,2-PhD: "))
#       5 exp=float(input("Enter years of experience: "))
# ----> 6 out=model.predict([[age,gen,el,exp]])
#       7 print("Your Predicted salary is:",out[0])
#
# NameError: name 'model' is not defined
